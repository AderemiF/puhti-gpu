# %% [markdown]
# ```bash
# SCRATCH_DIR=/scratch/project_2001220/<username>
# export OLLAMA_MODELS=${SCRATCH_DIR}/ollama/models
# export PATH=${SCRATCH_DIR}/ollama/bin:$PATH
# ```

# %% [markdown]
# ```bash
# cd ${SCRATCH_DIR}/ollama
# wget https://ollama.com/download/ollama-linux-amd64.tgz
# tar xzf ollama-linux-amd64.tgz
# rm ollama-linux-amd64.tgz
# ```

# %% [markdown]
# ```bash
# OLLAMA_KEEP_ALIVE=24h ollama serve &
# ollama pull ministral-3:3b
# ollama pull embeddinggemma
# # ollama run ministral-3:3b "Why is the sky blue?"
# ```

# %% [markdown]
# in case something goes wrong:
# ```bash
# top -U <username>
# kill <ollama process id>
# ```
